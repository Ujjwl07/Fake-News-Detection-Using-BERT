# %%
# Out:
# Loading weights: 100%|██████████| 201/201 [00:00<00:00, 7544.18it/s]
# Classification Report:
#
#               precision    recall  f1-score   support
#
#         Fake       1.00      1.00      1.00     23481
#         Real       1.00      1.00      1.00     21417
#
#     accuracy                           1.00     44898
#    macro avg       1.00      1.00      1.00     44898
# weighted avg       1.00      1.00      1.00     44898
#
#
# Correct Predictions:
# Donald Trump Sends Out Embarrassing New Year’s Eve Message; This is Disturbing -> 0
# Drunk Bragging Trump Staffer Started Russian Collusion Investigation -> 0
# Sheriff David Clarke Becomes An Internet Joke For Threatening To Poke People ‘In The Eye’ -> 0
# Trump Is So Obsessed He Even Has Obama’s Name Coded Into His Website (IMAGES) -> 0
# Pope Francis Just Called Out Donald Trump During His Christmas Speech -> 0
#
# Wrong Predictions:
# ...
